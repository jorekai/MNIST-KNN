# %%
# Keras datasets offers mnist as dataset
from keras.datasets import mnist
import matplotlib.pyplot as plt
# load dataset via keras api
(trainX, trainy), (testX, testy) = mnist.load_data()

# %%
# show shapes
print(trainX.shape, trainy.shape)
print(testX.shape, testy.shape)
# Out:
# (60000, 28, 28) (60000,)
# (10000, 28, 28) (10000,)

# %%
# plotting 36 images as matrix, adjusting title spacing and reshaping the input dimension
fig, ax = plt.subplots(6, 6, sharex='col', sharey='row', figsize=(10, 10))
img = 0
for i in range(6):
    for j in range(6):
        plottable_image = np.reshape(trainX[img], (28, 28))
        ax[j, i].set_title(trainy[img], fontsize=16)
        img += 1
        ax[j, i].imshow(plottable_image)
        ax[j, i].axis('off')
fig.tight_layout(h_pad=2.0, w_pad=-21)
